# %%
import numpy as np
import cv2, os
from PIL import Image
from IPython.display import Image

# %%
def face_search(img_path):
    img = cv2.imread(img_path)
    img = ResizeWithAspectRatio(img, 800, 500)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5, minSize=(20, 20))
    show = True
    print('Количество обнаруженных лиц: {0}'.format(len(faces)))
    while show:
        cv2.imshow("result", img)
        for (x, y, w, h) in faces:
            cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)
        if cv2.waitKey(10) == 27:
            new_img_path = ''.join(img_path.split('.')[:-1]) + '_result.png'
            cv2.imwrite(new_img_path, img)
            cv2.destroyAllWindows()
            show = False
            break
def ResizeWithAspectRatio(image, width=None, height=None, inter=cv2.INTER_AREA):
    dim = None
    (h, w) = image.shape[:2]
    if width is None and height is None:
        return image
    if width is None:
        r = height / float(h)
        dim = (int(w * r), height)
    else:
        r = width / float(w)
        dim = (width, int(h * r))
    return cv2.resize(image, dim, interpolation=inter)

faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
face_search(r'12_1.png')
# Out:
# Количество обнаруженных лиц: 1

# %%
# один человек
Image("12_1_result.png")

# %%
face_search(r'12_2.png')
# Out:
# Количество обнаруженных лиц: 1

# %%
# лицо в очках
Image("12_2_result.png")

# %%
face_search(r'12_3.png')
# Out:
# Количество обнаруженных лиц: 6

# %%
# много людей
Image("12_3_result.png")
